# %%
import pandas as pd

data_csv = pd.read_csv(r"C:\Users\Hp\OneDrive\Escritorio\Nara Python\project tasks_data_mito.csv")

# %%
data_csv

# %%
data_csv.shape
# Out:
# (51290, 14)

# %%
data_csv["new_quantity"] = data_csv["quantity"] *10
data_csv.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year  new_quantity
# ...

# %%
# why doesn't it multiply by 10, rather than repeating 10 times
data_csv.insert(10, "new_sales", data_csv.sales*10)

# %%
data_csv.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales                       new_sales  quantity  discount   profit  year
# ...

# %%
data_csv.drop("customer_name", axis=1, inplace = True)

# %%
data_csv.sort_values(by = "profit", ascending=False)
# Out:
#              order_id  order_date      segment        country   region  \
# 29530  CA-2013-118689  10-03-2013    Corporate  United States  Central
# 36239  CA-2014-140151   3/24/2014     Consumer  United States     West
# 48097  CA-2014-166709  11/18/2014     Consumer  United States     East
# 33011  CA-2013-117121  12/18/2013     Consumer  United States  Central
# 5522   CA-2011-116904   9/23/2011     Consumer  United States  Central
# ...               ...         ...          ...            ...      ...
# 37130  CA-2014-134845   4/18/2014  Home Office  United States     West
# 3775   CA-2011-169019   7/26/2011     Consumer  United States  Central
# 47195  US-2014-168116  11-05-2014    Corporate  United States    South
# 29212    TU-2013-9400   9/26/2013    Corporate         Turkey     EMEA
# 31884  CA-2013-108196  11/26/2013     Consumer  United States     East
#
#              product_id         category  \
# 29530   TEC-CO-10004722       Technology
# ...

# %%
data_csv[data_csv["region"] == "Africa"]
# Out:
#            order_id  order_date      segment      country  region  \
# 0      AG-2011-2040  01-01-2011     Consumer      Algeria  Africa
# 23     TZ-2011-7370  01-03-2011     Consumer     Tanzania  Africa
# 41     SU-2011-5190  01-04-2011     Consumer        Sudan  Africa
# 42     SU-2011-5190  01-04-2011     Consumer        Sudan  Africa
# 55     AO-2011-4910  01-06-2011    Corporate       Angola  Africa
# ...             ...         ...          ...          ...     ...
# 51252  OD-2014-9490  12/31/2014    Corporate  South Sudan  Africa
# 51253  AO-2014-7730  12/31/2014     Consumer       Angola  Africa
# 51262  TZ-2014-8350  12/31/2014     Consumer     Tanzania  Africa
# 51280  TZ-2014-8220  12/31/2014  Home Office     Tanzania  Africa
# 51286  MO-2014-2560  12/31/2014     Consumer      Morocco  Africa
#
#              product_id         category  \
# 0      OFF-TEN-10000025  Office Supplies
# 23     OFF-STI-10000388  Office Supplies
# 41     OFF-BOS-10004950  Office Supplies
# ...

# %%
data_csv[(data_csv["segment"] == "Corporate") & (data_csv["category"] == "Technology")]
# Out:
#              order_id  order_date    segment             country  \
# 28     MX-2011-140641  01-04-2011  Corporate              Mexico
# 32     MX-2011-140641  01-04-2011  Corporate              Mexico
# 55       AO-2011-4910  01-06-2011  Corporate              Angola
# 66       LE-2011-9590  01-07-2011  Corporate             Lebanon
# 92      ID-2011-20814  01-09-2011  Corporate           Indonesia
# ...               ...         ...        ...                 ...
# 51250   IN-2014-78228  12/31/2014  Corporate           Indonesia
# 51251  MX-2014-122511  12/31/2014  Corporate  Dominican Republic
# 51252    OD-2014-9490  12/31/2014  Corporate         South Sudan
# 51259  MX-2014-116267  12/31/2014  Corporate              Brazil
# 51275   ID-2014-54442  12/31/2014  Corporate         Philippines
#
#                region        product_id    category  \
# 28              North   TEC-AC-10001082  Technology
# 32              North   TEC-CO-10002998  Technology
# ...

# %%
data_csv[(data_csv["country"] == "Canada") | (data_csv["sales"] > "500")]
# Out:
#              order_id  order_date    segment      country          region  \
# 2        HU-2011-1220  01-01-2011   Consumer      Hungary            EMEA
# 5       IN-2011-47883  01-01-2011   Consumer    Australia         Oceania
# 6        CA-2011-1510  01-02-2011   Consumer       Canada          Canada
# 8       ID-2011-80230  01-03-2011   Consumer  New Zealand         Oceania
# 9        IZ-2011-4680  01-03-2011  Corporate         Iraq            EMEA
# ...               ...         ...        ...          ...             ...
# 51270   IN-2014-23754  12/31/2014  Corporate        China      North Asia
# 51271   IN-2014-75603  12/31/2014  Corporate        India    Central Asia
# 51275   ID-2014-54442  12/31/2014  Corporate  Philippines  Southeast Asia
# 51283   IN-2014-23754  12/31/2014  Corporate        China      North Asia
# 51288  MX-2014-114783  12/31/2014   Consumer       Mexico           North
#
#              product_id         category  \
# ...

# %%
# can't process values="sales"
data_csv.pivot_table(index="region", columns="year")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5436\1675221774.py:2: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   data_csv.pivot_table(index="region", columns="year")
#                 discount                                   profit             \
# year                2011      2012      2013      2014       2011       2012
# region
# Africa          0.205591  0.172789  0.137017  0.139963  13.906117  13.502194
# Canada          0.000000  0.000000  0.000000  0.000000  29.146452  54.919551
# Caribbean       0.143343  0.131353  0.137151  0.133202  15.082730  25.162592
# Central         0.143895  0.136971  0.133935  0.141397  26.863066  27.071195
# Central Asia    0.069832  0.060407  0.068297  0.070014  63.816888  65.559007
# EMEA            0.194181  0.212266  0.193807  0.189067   6.270819   5.074508
# ...

# %%
data_csv.pivot_table(index="category", columns="region", values="profit", aggfunc={"profit":"sum"})
# Out:
# region              Africa   Canada    Caribbean       Central  Central Asia  \
# category
# Furniture        16262.085  2613.24   6223.46000   54550.84010     48935.712
# Office Supplies  28480.053  7957.53  14818.27600  121314.72090     27104.500
# Technology       44129.493  7246.62  13529.58504  135538.42064     56439.975
#
# region                EMEA        East        North  North Asia    Oceania  \
# category
# Furniture        11534.136   3046.1658  30922.06800   52181.301  33626.434
# Office Supplies  14869.392  41014.5791  64403.39300   40926.105  33306.186
# Technology       17494.443  47462.0351  99272.49152   72471.015  54734.022
#
# region                 South  Southeast Asia        West
# category
# Furniture        22651.62810      -7269.7665  11504.9503
# Office Supplies  67495.99880       4173.2515  52609.8490
# Technology       50208.13928      20948.8440  44303.6496

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data_csv.sales, data_csv["profit"], color="red", s=30, edgecolor="green", label= "My chart")
plt.legend()
plt.xlabel("Sales"), plt.ylabel("Profit")
plt.show()

# %%
# concatenate country and region
data_csv["concat"] = data_csv["country"] + "(" + data_csv["region"] + ")"
